# %% [markdown]
# I'll be using the Bank Marketing dataset sourced from UCI repository, for application of Artificial Neural Networks for predictive purposes.
#
# Data source: [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014

# %% [markdown]
# Importing the libraries and dataset

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns

# %%
# importing the dataset
df = pd.read_csv('bank-additional-full.csv', sep = ';')

# %% [markdown]
# Exploratory Data Analysis and Visualizations

# %%
df.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
# Getting dataset and feature information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
# Getting numeric feature distribution
df.describe()
# Out:
#                age      duration  ...     euribor3m   nr.employed
# count  41188.00000  41188.000000  ...  41188.000000  41188.000000
# mean      40.02406    258.285010  ...      3.621291   5167.035911
# std       10.42125    259.279249  ...      1.734447     72.251528
# min       17.00000      0.000000  ...      0.634000   4963.600000
# 25%       32.00000    102.000000  ...      1.344000   5099.100000
# 50%       38.00000    180.000000  ...      4.857000   5191.000000
# 75%       47.00000    319.000000  ...      4.961000   5228.100000
# max       98.00000   4918.000000  ...      5.045000   5228.100000
#
# [8 rows x 10 columns]

# %%
# Checking for nulls/missing values
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# Listing numerical features (continuous and discreet) and categorical features
cat_features = [x for x in df.columns if df[x].dtypes == 'O']
num_features = [x for x in df.columns if df[x].dtypes !='O']

# %%
# Visualizing the numeric features with a simple pair plot
sns.pairplot(data = df[num_features])
